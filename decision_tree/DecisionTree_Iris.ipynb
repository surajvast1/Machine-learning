# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier

# %%
# Load Dataset
iris=load_iris()

# %%
iris['feature_names']
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
X = iris["data"][:,2:]
y=iris["target"]

# %%
# Splitting the dataset
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test= train_test_split(X,y,test_size=0.3)

# %%
# Train The Model
from sklearn import tree
classifier = tree.DecisionTreeClassifier()
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Make Prediction
predictions = classifier.predict(x_test)
predictions
# Out:
# array([2, 2, 1, 2, 2, 0, 2, 0, 2, 0, 1, 1, 2, 0, 0, 2, 0, 2, 1, 0, 0, 2,
#        0, 1, 0, 2, 0, 1, 0, 0, 1, 0, 0, 1, 1, 2, 0, 0, 2, 1, 1, 2, 2, 0,
#        2])

# %%
# Performance Measure
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,predictions))
# Out:
# 0.9111111111111111

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm=confusion_matrix(y_test,predictions)
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %%
# Classification Report
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       0.64      1.00      0.78         7
#            2       1.00      0.80      0.89        20
#
#     accuracy                           0.91        45
#    macro avg       0.88      0.93      0.89        45
# weighted avg       0.94      0.91      0.92        45

# %%
# Visualizing the decisoon tree
from sklearn.tree import export_graphviz
export_graphviz(
    classifier,
    out_file="iris_tree.dot",
    feature_names=iris.feature_names[2:],
    class_names=iris.target_names,
    rounded=True,
    filled=True
)

# %%
# %ls
# Out:
# DecisionTree_Iris.ipynb  destree.ipynb  iris_tree.dot  iris_tree.png

# %%
    # !dot -Tpng iris_tree.dot -o iris_tree.png

# %%
from IPython.display import Image
Image (filename='iris_tree.png')

# %%
from sklearn.tree import plot_tree
plot_tree(classifier)
# Out:
# [Text(0.4, 0.9375, 'x[0] <= 2.45\ngini = 0.658\nsamples = 105\nvalue = [32, 43, 30]'),
#  Text(0.3, 0.8125, 'gini = 0.0\nsamples = 32\nvalue = [32, 0, 0]'),
#  Text(0.5, 0.8125, 'x[1] <= 1.65\ngini = 0.484\nsamples = 73\nvalue = [0, 43, 30]'),
#  Text(0.2, 0.6875, 'x[0] <= 5.0\ngini = 0.046\nsamples = 42\nvalue = [0, 41, 1]'),
#  Text(0.1, 0.5625, 'gini = 0.0\nsamples = 40\nvalue = [0, 40, 0]'),
#  Text(0.3, 0.5625, 'x[1] <= 1.55\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.2, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.4, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8, 0.6875, 'x[0] <= 5.05\ngini = 0.121\nsamples = 31\nvalue = [0, 2, 29]'),
#  Text(0.7, 0.5625, 'x[1] <= 1.9\ngini = 0.408\nsamples = 7\nvalue = [0, 2, 5]'),
#  Text(0.6, 0.4375, 'x[0] <= 4.95\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3]'),
#  Text(0.5, 0.3125, 'x[1] <= 1.75\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
# ...

# %%
# New Predictions
classifier.predict_proba([[5,1.5]]) # a petal length of 5 and a petal width of 1.5
# Out:
# array([[0., 1., 0.]])

# %%
classifier.predict([[5,1.5]])
# Out:
# array([1])

# %%
# Build Decision Tree Model With Max_Depth=2
tree_clf=DecisionTreeClassifier(max_depth=2)
tree_clf.fit(X,y)
DecisionTreeClassifier(max_depth=2)
y_pred=classifier.predict(x_test)
y_pred
# Out:
# array([2, 2, 1, 2, 2, 0, 2, 0, 2, 0, 1, 1, 2, 0, 0, 2, 0, 2, 1, 0, 0, 2,
#        0, 1, 0, 2, 0, 1, 0, 0, 1, 0, 0, 1, 1, 2, 0, 0, 2, 1, 1, 2, 2, 0,
#        2])

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9111111111111111

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm=confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %%
from sklearn.tree import export_graphviz
export_graphviz(
    classifier,
    out_file="iris_tree2.dot",
    feature_names=iris.feature_names[2:],
    class_names=iris.target_names,
    rounded=True,
    filled=True
)

# %%
# !dot -Tpng iris_tree.dot -o iris_tree.png

# %%
from IPython.display import Image
Image (filename='iris_tree.png')

# %%
# New Prediction
tree_clf.predict_proba([[5,1.5]]) # a petal length of 5 and a petal width of 1.5
# Out:
# array([[0.        , 0.90740741, 0.09259259]])

# %%
tree_clf.predict([[5,1.5]])
# Out:
# array([1])
