# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
iris['feature_names']
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris['target_names']
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
X = iris["data"][:,2:]
X
# Out:
# array([[1.4, 0.2],
#        [1.4, 0.2],
#        [1.3, 0.2],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.7, 0.4],
#        [1.4, 0.3],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.5, 0.1],
#        [1.5, 0.2],
#        [1.6, 0.2],
#        [1.4, 0.1],
#        [1.1, 0.1],
#        [1.2, 0.2],
#        [1.5, 0.4],
#        [1.3, 0.4],
#        [1.4, 0.3],
#        [1.7, 0.3],
#        [1.5, 0.3],
#        [1.7, 0.2],
#        [1.5, 0.4],
#        [1. , 0.2],
#        [1.7, 0.5],
#        [1.9, 0.2],
#        [1.6, 0.2],
#        [1.6, 0.4],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.6, 0.2],
#        [1.6, 0.2],
#        [1.5, 0.4],
#        [1.5, 0.1],
#        [1.4, 0.2],
#        [1.5, 0.2],
#        [1.2, 0.2],
#        [1.3, 0.2],
#        [1.4, 0.1],
#        [1.3, 0.2],
#        [1.5, 0.2],
#        [1.3, 0.3],
#        [1.3, 0.3],
#        [1.3, 0.2],
#        [1.6, 0.6],
#        [1.9, 0.4],
#        [1.4, 0.3],
#        [1.6, 0.2],
# ...

# %%
y = iris['target']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
from sklearn import tree
classifier = tree.DecisionTreeClassifier()
classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import r2_score
  
y_pred = classifier.predict(X_test)
y_pred

from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# 0.8964723926380368

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %%
from sklearn.tree import export_graphviz

export_graphviz(
    classifier,
    out_file="iris_tree.dot",
    feature_names=iris.feature_names[2:],
    class_names=iris.target_names,
    filled=True
)

# %%
# %ls
# Out:
# DecisionTree_Iris.ipynb  destree.ipynb  iris_tree.dot

# %%
from subprocess import call
from IPython.display import Image

call(['dot', '-Tpng', 'iris_tree.dot', '-o', 'iris_tree.png'])

# Display the PNG image
Image(filename='iris_tree.png')

# %%
treeclf = tree.DecisionTreeClassifier(max_depth=2)
treeclf.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
y_preda = treeclf.predict(X_test)
y_preda

from sklearn.metrics import r2_score
print(r2_score(y_test,y_preda))
# Out:
# 0.9309815950920245

# %%
from sklearn.tree import export_graphviz

export_graphviz(
    treeclf,
    out_file="iris_2.dot",
    feature_names = iris.feature_names[2:],
    class_names=iris.target_names,
    rounded=True,
    filled = True
)

# %%
! dot -Tpng iris_2.dot -o iris_2.png

# %%
from IPython.display import Image
Image(filename='iris_2.png')
